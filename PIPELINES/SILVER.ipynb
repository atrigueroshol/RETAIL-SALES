# %% [markdown]
# # SILVER LAYER

# %% [markdown]
# In the Silver layer we are going to:
# - Remove duplicates
# - Create new columns year, month and day

# %% [markdown]
# Removing duplicates

# %%
# %sql
CREATE OR REPLACE TEMP VIEW raw_dedup_view AS
SELECT DISTINCT *
FROM retail_sales.bronze.raw_sales
WHERE processed = FALSE;

MERGE INTO retail_sales.silver.raw_dedup A
USING raw_dedup_view B
ON A.Transaction_ID = B.Transaction_ID

WHEN NOT MATCHED THEN
  INSERT *

# %% [markdown]
# Creating new columns

# %% [markdown]
# Update the processed tag in the bronze table to True

# %%
# %sql
UPDATE retail_sales.bronze.raw_sales
SET Processed = TRUE
WHERE Processed = FALSE
