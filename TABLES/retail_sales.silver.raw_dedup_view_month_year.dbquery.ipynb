-- %%
CREATE OR REPLACE TABLE retail_sales.silver.raw_dedup_view_month_year (
  Transaction_ID INT,
  Date_t DATE,
  Date_Year INT,
  Date_Month INT,
  Date_Day INT,
  Customer_ID STRING,
  Gender STRING,
  Age INT,
  Product_Category STRING,
  Quantity INT,
  Price_per_Unit INT,
  Total_Amount INT,
  Processed BOOLEAN,
  Inserted_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP()
);
