-- %%
CREATE OR REPLACE TABLE retail_sales.gold.agg_sales (
  Date_Year INTEGER,
  Date_Month INTEGER,
  Product_Category STRING,
  total_sales INTEGER,
  total_quantity INTEGER,
  total_customers INTEGER
);
