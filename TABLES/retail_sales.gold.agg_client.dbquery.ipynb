-- %%
CREATE OR REPLACE TABLE retail_sales.gold.agg_client (
  Date_Year INTEGER,
  Date_Month INTEGER,
  Gender STRING,
  Age INTEGER,
  total_transactions INTEGER,
  total_spent INTEGER,
  avg_ticket INTEGER
);
