-- %%
CREATE OR REPLACE TABLE retail_sales.silver.raw_dedup(
  Transaction_ID INTEGER,
  Date_t DATE,
  Customer_ID STRING,
  Gender STRING,
  Age INTEGER,
  Product_Category STRING,
  Quantity INTEGER,
  Price_per_Unit INTEGER,
  Total_Amount INTEGER,
  Processed BOOLEAN,
  Inserted_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP()
);
